# %% [markdown]
# <a href="https://colab.research.google.com/github/zslmrhb/RoboMaster/blob/main/Power_Rune_Plan_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from time import time

# %% [markdown]
# # Load Image

# %%
img = cv2.imread("/content/drive/MyDrive/Colab Notebooks/0750.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
